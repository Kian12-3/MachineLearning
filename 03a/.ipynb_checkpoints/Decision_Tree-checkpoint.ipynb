# %%
cd C:\Users\mc_kleach26\.cache\kagglehub\datasets\sakshisatre\titanic-dataset\versions\2
# Out:
# C:\Users\mc_kleach26\.cache\kagglehub\datasets\sakshisatre\titanic-dataset\versions\2

# %%
import pandas as pd
from sklearn.model_selection import train_test_split  
from sklearn.tree import DecisionTreeClassifier, plot_tree  
from sklearn.metrics import accuracy_score, classification_report 
import matplotlib.pyplot as plt 
import kagglehub

# %%
# Download the Titanic dataset from Kaggle
path = kagglehub.dataset_download("sakshisatre/titanic-dataset")
print("Path to dataset files:", path)

df = pd.read_csv("The Titanic Dataset.csv")
# Out:
# Path to dataset files: C:\Users\mc_kleach26\.cache\kagglehub\datasets\sakshisatre\titanic-dataset\versions\2

# %%
df
# Out:
#          1       2         3                                       4       5  \
# 0       sn  pclass  survived                                     NaN  gender
# 1        1       3         0                             Mr. Anthony    male
# 2        1       3         0                             Mr. Anthony    male
# 3        2       3         0                   Master. Eugene Joseph    male
# 4        3       2         0             Abbott, Mr. Rossmore Edward     NaN
# ...    ...     ...       ...                                     ...     ...
# 1297  1296       2         0  Yrois, Miss. Henriette ("Mrs Harbeck")  female
# 1298  1297       3         0                    Zabour, Miss. Hileni  female
# 1299  1298       3         0               Zakarian, Mr. Mapriededer    male
# 1300  1299       3         0                     Zakarian, Mr. Ortin    male
# 1301  1300       3         0                      Zimmerman, Mr. Leo    male
#
# ...
